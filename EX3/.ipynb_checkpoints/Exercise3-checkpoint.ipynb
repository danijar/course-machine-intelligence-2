# %%
import random
import glob
from scipy import ndimage
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
def sample_patches(images, count=5000, size=16):
    patches = np.empty((count, size, size))
    for i in range(count):
        image = random.choice(images)
        x = int(random.random() * (image.shape[0] - size))
        y = int(random.random() * (image.shape[1] - size))
    patches[i] = image[x: x + size, y: y + size]
    return patches

def show_patches(patches, rows, cols, title='Patches', size=10):
    assert len(patches) == rows * cols
    fig, ax = plt.subplots(
        nrows=rows, ncols=cols, figsize=(size, size / cols * rows),
        subplot_kw={'xticks': [], 'yticks': []})
    fig.suptitle(title)
    for x, y in itertools.product(range(rows), range(cols)):
        patch = patches[x * cols + y]
        ax[x, y].get_xaxis().set_visible(False)
        ax[x, y].imshow(patch, cmap=plt.cm.gray_r, interpolation='nearest')
    plt.show()

def tile_partition(image, width=10, height=20):
    img_height, img_width = image.shape
    assert img_height % height == 0 and img_width % width == 0
    for i in range(int(img_height / height)):
        for j in range(int(img_width / width)):
            yield image[i*height:(i+1)*height, j*width:(j+1)*width]

def tile_stitching(tiles, image):
    img_height, img_width = image.shape
    count, height, width = tiles.shape
    stitched = np.zeros(image.shape)
    row_count = int(img_height / height)
    col_count = int(img_width / width)
    for i in range(row_count):
        for j in range(col_count):
            stitched[i*height:(i+1)*height, j*width:(j+1)*width] = tiles[i*col_count+j]
    return stitched

def calculate_pcs(data, num_pcs):
    _, eigvecs = np.linalg.eigh(np.cov(data))
    eigvecs = eigvecs[::-1]
    return eigvecs[:num_pcs]

def reconstruct_tile(data, pcs):
    # data -= np.mean(data)
    transformed = np.dot(pcs, data)
    reconstructed = np.dot(pcs.T, transformed)
    return reconstructed

def reconstruct_image(picture, num_pcs, orig_tiles_pcs=[], show=True):
    tiles = np.array(list(tile_partition(picture)))
    reconstructed_tiles = np.zeros(tiles.shape)
    tiles_pcs = [None] * len(tiles)
    for i, tile in enumerate(tiles):
        tiles_pcs[i] = calculate_pcs(tile, num_pcs)
        pcs = orig_tiles_pcs[i] if orig_tiles_pcs else tiles_pcs[i]
        reconstructed_tiles[i] = reconstruct_tile(tile, pcs)
    reconstructed_image = tile_stitching(reconstructed_tiles, picture)
    if show:
        plt.imshow(reconstructed_image, cmap=plt.cm.gray, interpolation='nearest')
        plt.show()
    sqerr = np.mean((picture - reconstructed_image)**2)
    print(n,' principal components, square error is', sqerr)

# %%
# Exercise 3.1


pictures = [ndimage.imread(x) for x in glob.glob('imgpca/*.jpg')]

nature_pic = np.random.RandomState(5).choice(pictures, 1)[0]
nature_pic = nature_pic[:160, :320].astype(np.float64)
nature_pic -= np.mean(nature_pic)
plt.imshow(nature_pic, cmap=plt.cm.gray, interpolation='nearest')
plt.show()

for n in [1, 2, 4, 8, 16, 100]:
    tiles_pcs = reconstruct_image(nature_pic, n)

nature_pic_2 = np.random.RandomState(1).choice(pictures, 1)[0]
nature_pic_2 = nature_pic_2[:160, :320].astype(np.float64)
nature_pic_2 -= np.mean(nature_pic_2)
plt.imshow(nature_pic_2, cmap=plt.cm.gray, interpolation='nearest')
plt.show()

tiles_pcs_2 = reconstruct_image(nature_pic_2, 1, tiles_pcs)
# Out:
# 1  principal components, square error is 7646.81697751
# 2  principal components, square error is 7594.92198546
# 4  principal components, square error is 7501.73671531
# 8  principal components, square error is 7254.79594358
# 16  principal components, square error is 6795.10500477
# 100  principal components, square error is 6581.67744255
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-43a8a1bfc358> in <module>()
#      19 plt.show()
#      20
# ---> 21 tiles_pcs_2 = reconstruct_image(nature_pic_2, 1, tiles_pcs)
#
# <ipython-input-54-e162fd02ccba> in reconstruct_image(picture, num_pcs, orig_tiles_pcs, show)
#      55     for i, tile in enumerate(tiles):
#      56         tiles_pcs[i] = calculate_pcs(tile, num_pcs)
# ---> 57         pcs = orig_tiles_pcs[i] if i < len(orig_tiles_pcs) else tiles_pcs[i]
# ...

# %%
a = [1,2,5]
print(3 in a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-fe7521a4a9ec> in <module>()
#       1 a = [1,2,5]
# ----> 2 print(3 in keys(a))
#
# NameError: name 'keys' is not defined
